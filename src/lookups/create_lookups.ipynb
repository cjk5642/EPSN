# %%
import pandas as pd
import datetime
import os
import numpy as np
from collections import defaultdict
import sys
import itertools
import json
import requests
import re
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm

sys.path.append('/content/drive/MyDrive/Classes/Spring 2022/INFO606: Network Science/Project/src/lookups/')
from error import SportNotAllowedError

# %%
class CollectSeasons:
  seasons = None

  def __init__(self):
    self.json_path = "/content/drive/MyDrive/Classes/Spring 2022/INFO606: Network Science/Project/data/seasons.json"
    self.__INIT_DATE__ = {'mlb': datetime.datetime(1876, 4, 22), 
                          'nba': datetime.datetime(1946, 11, 1), 
                          'ncaaf': datetime.datetime(2000, 8, 26),  
                          'nfl': datetime.datetime(1970, 9, 18), 
                          'nhl': datetime.datetime(1918, 12, 21),
                          'ncaab': datetime.datetime(1947, 1, 1)}
    self.__SPORTS__ = {'nhl': 'https://www.hockey-reference.com/', 
              'mlb': 'https://www.baseball-reference.com/', 
              'nfl': 'https://www.pro-football-reference.com/', 
              'nba': 'https://www.basketball-reference.com/',
              'ncaaf': 'https://www.sports-reference.com/cfb/',
              'ncaab': 'https://www.sports-reference.com/cbb/'}

    # establish seasons and output years
    if CollectSeasons.seasons is None:
      CollectSeasons.seasons = self._collect_seasons()
    
    # jsonify seasons
    self._create_season_json()

  def _collect_seasons(self) -> None:
    sports = {sport: self._collect_seasons_helper(sport) for sport in tqdm(list(self.__SPORTS__.keys()))}
    return sports

  def _create_season_link(self, sport: str) -> str:
    # collect the urls for each sport
    if sport in ['nhl', 'mlb', 'nba']:
      season_link = self.__SPORTS__[sport] + 'leagues/'
    elif sport in ['nfl', 'ncaaf']:
      season_link = self.__SPORTS__[sport] + 'years/'
    else:
      season_link = self.__SPORTS__[sport] + 'seasons/'
    return season_link

  def _collect_seasons_helper(self, sport: str) -> dict: 
    # extract link by sport
    season_link = self._create_season_link(sport)
    
    # collect the reponse and parse the data to fit the data we want and save the data
    if sport in ['nhl', 'nba']:
      response = pd.read_html(season_link)[0]
      response.columns = response.columns.droplevel()
      response[['Year', 'End Year']] = response['Season'].str.split('-', expand = True)
      response['Year'] = response['Year'].astype(int)
      response = response[response['Year'] >= self.__INIT_DATE__[sport].year].reset_index(drop = True)

    elif sport in ['nfl', 'ncaaf']:
      response = pd.read_html(season_link)[0]
      response = response[response['Year'] >= self.__INIT_DATE__[sport].year].reset_index(drop = True)

    elif sport == 'mlb':
      response = pd.read_html(season_link)[1]
      response['Year'] = response['Year'].ffill()
      response['Year'] = response['Year'].astype(int)
      response = response[response['Year'] >= self.__INIT_DATE__[sport].year].reset_index(drop = True)

    elif sport == 'ncaab':
      response = pd.read_html(season_link)[0]
      response['Season'] = response['Season'].apply(lambda x: x.rstrip(' Summary'))
      response[['Year', 'End Year']] = response['Season'].str.split('-', expand = True)
      response = response[response['Year'] != 'Season'].reset_index(drop = True)
      response['Year'] = response['Year'].astype(int)
      response = response[response['Year'] >= self.__INIT_DATE__[sport].year].reset_index(drop = True)
    
    else:
      raise SportNotAllowedError(sport)
    
    min_year = int(response['Year'].min())
    max_year = int(response['Year'].max())
    r = dict(min_year = min_year, max_year = max_year, season_link = season_link)
    return r

  def _create_season_json(self) -> None:
    if not os.path.exists(self.json_path):
      with open(self.json_path, 'w') as file:
        json.dump(CollectSeasons.seasons, file)
    return None

class CollectTeamsBySeason:
  sports_team_by_season = None

  def __init__(self, collectseasons):
    self.teambysport_path = "/content/drive/MyDrive/Classes/Spring 2022/INFO606: Network Science/Project/data/teams.json"
    self.seasons = collectseasons.seasons
    self.sports = list(self.seasons.keys())
    CollectTeamsBySeason.sports_team_by_season = {sport: None for sport in self.sports}

    # collect sports teams
    if not os.path.exists(self.teambysport_path):
      for sport in self.sports:
        if CollectTeamsBySeason.sports_team_by_season[sport] is None:
          print(f"Working on {sport}...")
          CollectTeamsBySeason.sports_team_by_season[sport] = self._collect_team_by_season(sport)
          self._create_team_json()
    else:
      with open(self.teambysport_path, 'r') as file:
        CollectTeamsBySeason.sports_team_by_season = json.load(file)

  def _extract_team_links_helper(self, teams, base_link: str):
    team_end_links = {}
    if teams is not None:
      if 'pro' in base_link:
        teams = teams.find_all(attrs = {'data-stat': 'team'})
      elif "sports-reference" in base_link:
        teams = teams.find_all(attrs = {'data-stat': 'school_name'})
      else:
        teams = teams.find_all(attrs = {'data-stat': 'team_name'})
      for t in teams:
        t_find = t.find('a')
        if t_find is None:
          continue
        link = f"{base_link}{t_find['href']}"
        team_end_links[t_find.text] = link
    return team_end_links

  def _extract_team_links(self, sport:str, year: str, link: str) -> dict:
    # collect the mlb
    if sport in ['mlb']:
      url = f"{link}/majors/{year}.shtml"
      soup = BeautifulSoup(requests.get(url).content, 'html.parser')
      teams = soup.find(id=re.compile('teams_standard_batting+'))
      team_end_links = self._extract_team_links_helper(teams, base_link = "https://www.baseball-reference.com")
    
    # collect the nhl
    if sport in ['nhl']:
      url = f"{link}/NHL_{year+1}.html"
      soup = BeautifulSoup(requests.get(url).content, 'html.parser')
      teams = soup.find(id=re.compile("standings+"))
      team_end_links = self._extract_team_links_helper(teams, base_link = "https://www.hockey-reference.com")
    
    # collect the nfl
    if sport in ['nfl']:
      url = f"{link}{year}"
      soup = BeautifulSoup(requests.get(url).content, 'html.parser')
      teams = soup.find(id=re.compile("AFC|NFC"))
      team_end_links = self._extract_team_links_helper(teams, base_link = "https://www.pro-football-reference.com")

    # collect the ncaaf and ncaab
    if sport in ['ncaaf', 'ncaab']:
      url = f"{link}{year}.html"
      soup = BeautifulSoup(requests.get(url).content, 'html.parser')
      conferences = [c.find('a')['href'] for c in soup.find_all(attrs = {'data-stat': 'conf_name'}) if c.find('a') is not None]
      team_end_links = {}
      for c in conferences:
        conf_url = f"https://www.sports-reference.com{c}"
        conf_soup = BeautifulSoup(requests.get(conf_url).content, 'html.parser')
        teams = conf_soup.find(id = 'standings')
        team_data = self._extract_team_links_helper(teams, base_link = "https://www.sports-reference.com")
        team_end_links.update(team_data)

    if sport in ['nba']:
      if 1969 >= year >= 1949:
        url = f"{link}NBA_{year+1}.html"
        soup = BeautifulSoup(requests.get(url).content, 'html.parser')
        teams = soup.find(id=re.compile("divs_standings_"))      
      elif 2014 >= year > 1969:
        url = f"{link}NBA_{year+1}.html"
        soup = BeautifulSoup(requests.get(url).content, 'html.parser')
        teams = soup.find(id=re.compile("divs_standings_+"))
      elif year >= 2014:
        url = f"{link}NBA_{year+1}.html"
        soup = BeautifulSoup(requests.get(url).content, 'html.parser')
        teams = soup.find(id=re.compile("confs_standings_+"))
      else:
        url = f"{link}BAA_{year+1}.html"
        soup = BeautifulSoup(requests.get(url).content, 'html.parser')
        teams = soup.find(id = 'divs_standings_')        
      team_end_links = self._extract_team_links_helper(teams, base_link = "https://www.basketball-reference.com")
    return team_end_links

  def _collect_team_by_season(self, sport: str) -> None:
    min_year = self.seasons[sport]['min_year']
    max_year = self.seasons[sport]['max_year']
    season_years = range(min_year, max_year+1)
    link = self.seasons[sport]['season_link']
    sport_data = {year:self._extract_team_links(sport, year, link) for year in tqdm(season_years)}
    return sport_data

  def _create_team_json(self) -> None:
    with open(self.teambysport_path, 'w') as file:
      json.dump(CollectTeamsBySeason.sports_team_by_season, file)
    return None

# %%
class SportSchedules:
  def __init__(self):
    self._establish_schedules_dir()

  def _establish_schedules_dir(self) -> None:
    schedule_path = "/content/drive/MyDrive/Classes/Spring 2022/INFO606: Network Science/Project/data/schedules"
    if not os.path.isdir(schedule_path):
      os.makedirs(schedule_path)
    return None

  def collect_sport_schedules(self, ):
   pass

# %%
class NFLSchedules:
  schedule = None
  def __init__(self, collectseasons):
    self.seasons = collectseasons.seasons
    if NFLSchedules.schedule is None:
      NFLSchedules.schedule = self._collect_and_save_weeks()

  def _collect_and_save_weeks(self) -> dict:
    print("Working on NFL Schedules")
    frames = []
    nfl_seasons = self.seasons['nfl']
    year_range = range(nfl_seasons['min_year'], nfl_seasons['max_year'])
    for year in tqdm(year_range):
      url = f"https://www.pro-football-reference.com/years/{year}/games.htm"
      page = pd.read_html(url)[0]
      page['year'] = year
      page = page[['Week', 'year']].drop_duplicates()
      page = page[page['Week'] != 'Week'].dropna().reset_index(drop = True).reset_index()
      frames.append(page)
    schedule = pd.concat(frames, axis = 0, ignore_index = True)
    schedule['type_week'] = schedule['Week'].apply(lambda x: 'regular' if x.isnumeric() else 'post')
    schedule = schedule.rename({'index': 'week_num'}, axis = 1)
    schedule['week_num'] += 1

    schedule_json = {}
    for year in year_range:
      data = {}
      temp = schedule[schedule['year'] == year]
      data['regular'] = list(map(str, temp.loc[temp['type_week'] == 'regular', 'week_num'].values))
      data['post'] = list(map(str, temp.loc[temp['type_week'] == 'post', 'week_num'].values))
      data['name'] = list(map(str, temp['Week'].values))
      schedule_json[year] = data

    return schedule_json

class MLBSchedules:
  schedule = None
  def __init__(self, collectseasons):
    self.seasons = collectseasons.seasons

    #if MLBSchedules.schedule is None:
    #  MLBSchedules.schedule = self._collect_and_save_splits()

  def _collect_and_save_splits(self):
    print("Working on MLB Schedules...")
    mlb_seasons = self.seasons['mlb']
    year_range = range(mlb_seasons['min_year'], mlb_seasons['max_year'])
    data_split = ['regular', 'post']
    collections = {}
    for year in tqdm(year_range):
      url = f"https://www.baseball-reference.com/leagues/majors/{year}-schedule.shtml"
      response = BeautifulSoup(requests.get(url).content, 'html.parser')
      splits = response.find_all("div", attrs = {"class": 'section_content'})[:-1]
      if len(splits) == 2:
        split_data = dict(zip(data_split, splits))
        for ds in data_split:
          all_h3 = split_data[ds].find_all('h3')
          all_h3 = list(map(lambda x: x.text, all_h3))
          if 'Today' not in all_h3[0] or 'Today' not in all_h3[-1]:
            split_range = [pd.to_datetime(all_h3[0]), pd.to_datetime(all_h3[-1])]
          else:
            split_range = []
          split_data[ds] = split_range
        collections[year] = split_data
      else:
        split_data = {'regular': splits[0], 'post': []}
        all_h3 = split_data['regular'].find_all('h3')
        all_h3 = list(map(lambda x: x.text, all_h3))
        split_range = [pd.to_datetime(all_h3[0]), pd.to_datetime(all_h3[-1])]
        split_data['regular'] = split_range
        collections[year] = split_data
      
    return collections

class NBASchedules:
  pass

class NHLSchedules:
  pass

class NCAAFSchedules:
  pass

class NCAABSchedules:
  pass

# %%
seasons = CollectSeasons()

# %%
s = MLBSchedules(seasons)._collect_and_save_splits()
# Out:
# Working on MLB Schedules...
#   0%|          | 0/146 [00:00<?, ?it/s]

# %%
s
# Out:
# {1876: {'post': [],
#   'regular': [Timestamp('1876-04-22 00:00:00'),
#    Timestamp('1876-10-21 00:00:00')]},
#  1877: {'post': [],
#   'regular': [Timestamp('1877-04-30 00:00:00'),
#    Timestamp('1877-10-06 00:00:00')]},
#  1878: {'post': [],
#   'regular': [Timestamp('1878-05-01 00:00:00'),
#    Timestamp('1878-09-30 00:00:00')]},
#  1879: {'post': [],
#   'regular': [Timestamp('1879-05-01 00:00:00'),
#    Timestamp('1879-09-30 00:00:00')]},
#  1880: {'post': [],
#   'regular': [Timestamp('1880-05-01 00:00:00'),
#    Timestamp('1880-10-01 00:00:00')]},
#  1881: {'post': [],
#   'regular': [Timestamp('1881-04-30 00:00:00'),
#    Timestamp('1881-09-30 00:00:00')]},
#  1882: {'post': [],
#   'regular': [Timestamp('1882-05-01 00:00:00'),
#    Timestamp('1882-10-02 00:00:00')]},
#  1883: {'post': [],
#   'regular': [Timestamp('1883-05-01 00:00:00'),
#    Timestamp('1883-09-30 00:00:00')]},
#  1884: {'post': [],
#   'regular': [Timestamp('1884-04-17 00:00:00'),
#    Timestamp('1884-10-19 00:00:00')]},
#  1885: {'post': [],
#   'regular': [Timestamp('1885-04-18 00:00:00'),
#    Timestamp('1885-10-10 00:00:00')]},
#  1886: {'post': [],
#   'regular': [Timestamp('1886-04-17 00:00:00'),
#    Timestamp('1886-10-15 00:00:00')]},
#  1887: {'post': [],
#   'regular': [Timestamp('1887-04-16 00:00:00'),
#    Timestamp('1887-10-10 00:00:00')]},
#  1888: {'post': [],
#   'regular': [Timestamp('1888-04-18 00:00:00'),
#    Timestamp('1888-10-17 00:00:00')]},
#  1889: {'post': [],
#   'regular': [Timestamp('1889-04-17 00:00:00'),
#    Timestamp('1889-10-15 00:00:00')]},
#  1890: {'post': [],
#   'regular': [Timestamp('1890-04-17 00:00:00'),
#    Timestamp('1890-10-15 00:00:00')]},
#  1891: {'post': [],
#   'regular': [Timestamp('1891-04-08 00:00:00'),
#    Timestamp('1891-10-06 00:00:00')]},
#  1892: {'post': [],
#   'regular': [Timestamp('1892-04-12 00:00:00'),
#    Timestamp('1892-10-15 00:00:00')]},
#  1893: {'post': [],
#   'regular': [Timestamp('1893-04-27 00:00:00'),
#    Timestamp('1893-09-30 00:00:00')]},
#  1894: {'post': [],
#   'regular': [Timestamp('1894-04-19 00:00:00'),
#    Timestamp('1894-09-30 00:00:00')]},
#  1895: {'post': [],
#   'regular': [Timestamp('1895-04-18 00:00:00'),
#    Timestamp('1895-09-30 00:00:00')]},
#  1896: {'post': [],
#   'regular': [Timestamp('1896-04-16 00:00:00'),
#    Timestamp('1896-09-26 00:00:00')]},
#  1897: {'post': [],
#   'regular': [Timestamp('1897-04-19 00:00:00'),
#    Timestamp('1897-10-03 00:00:00')]},
#  1898: {'post': [],
#   'regular': [Timestamp('1898-04-15 00:00:00'),
#    Timestamp('1898-10-15 00:00:00')]},
#  1899: {'post': [],
#   'regular': [Timestamp('1899-04-14 00:00:00'),
#    Timestamp('1899-10-15 00:00:00')]},
#  1900: {'post': [],
#   'regular': [Timestamp('1900-04-19 00:00:00'),
#    Timestamp('1900-10-14 00:00:00')]},
#  1901: {'post': [],
#   'regular': [Timestamp('1901-04-18 00:00:00'),
#    Timestamp('1901-10-06 00:00:00')]},
#  1902: {'post': [],
#   'regular': [Timestamp('1902-04-17 00:00:00'),
#    Timestamp('1902-10-05 00:00:00')]},
#  1903: {'post': [Timestamp('1903-10-01 00:00:00'),
#    Timestamp('1903-10-13 00:00:00')],
#   'regular': [Timestamp('1903-04-16 00:00:00'),
#    Timestamp('1903-09-29 00:00:00')]},
#  1904: {'post': [],
#   'regular': [Timestamp('1904-04-14 00:00:00'),
#    Timestamp('1904-10-10 00:00:00')]},
#  1905: {'post': [Timestamp('1905-10-09 00:00:00'),
#    Timestamp('1905-10-14 00:00:00')],
#   'regular': [Timestamp('1905-04-14 00:00:00'),
#    Timestamp('1905-10-08 00:00:00')]},
#  1906: {'post': [Timestamp('1906-10-09 00:00:00'),
#    Timestamp('1906-10-14 00:00:00')],
#   'regular': [Timestamp('1906-04-12 00:00:00'),
#    Timestamp('1906-10-07 00:00:00')]},
#  1907: {'post': [Timestamp('1907-10-08 00:00:00'),
#    Timestamp('1907-10-12 00:00:00')],
#   'regular': [Timestamp('1907-04-11 00:00:00'),
#    Timestamp('1907-10-06 00:00:00')]},
#  1908: {'post': [Timestamp('1908-10-10 00:00:00'),
#    Timestamp('1908-10-14 00:00:00')],
#   'regular': [Timestamp('1908-04-14 00:00:00'),
#    Timestamp('1908-10-08 00:00:00')]},
#  1909: {'post': [Timestamp('1909-10-08 00:00:00'),
#    Timestamp('1909-10-16 00:00:00')],
#   'regular': [Timestamp('1909-04-12 00:00:00'),
#    Timestamp('1909-10-07 00:00:00')]},
#  1910: {'post': [Timestamp('1910-10-17 00:00:00'),
#    Timestamp('1910-10-23 00:00:00')],
#   'regular': [Timestamp('1910-04-14 00:00:00'),
#    Timestamp('1910-10-15 00:00:00')]},
#  1911: {'post': [Timestamp('1911-10-14 00:00:00'),
#    Timestamp('1911-10-26 00:00:00')],
#   'regular': [Timestamp('1911-04-12 00:00:00'),
#    Timestamp('1911-10-12 00:00:00')]},
#  1912: {'post': [Timestamp('1912-10-08 00:00:00'),
#    Timestamp('1912-10-16 00:00:00')],
#   'regular': [Timestamp('1912-04-11 00:00:00'),
#    Timestamp('1912-10-06 00:00:00')]},
#  1913: {'post': [Timestamp('1913-10-07 00:00:00'),
#    Timestamp('1913-10-11 00:00:00')],
#   'regular': [Timestamp('1913-04-09 00:00:00'),
#    Timestamp('1913-10-05 00:00:00')]},
#  1914: {'post': [Timestamp('1914-10-09 00:00:00'),
#    Timestamp('1914-10-13 00:00:00')],
#   'regular': [Timestamp('1914-04-13 00:00:00'),
#    Timestamp('1914-10-10 00:00:00')]},
#  1915: {'post': [Timestamp('1915-10-08 00:00:00'),
#    Timestamp('1915-10-13 00:00:00')],
#   'regular': [Timestamp('1915-04-10 00:00:00'),
#    Timestamp('1915-10-07 00:00:00')]},
#  1916: {'post': [Timestamp('1916-10-07 00:00:00'),
#    Timestamp('1916-10-12 00:00:00')],
#   'regular': [Timestamp('1916-04-12 00:00:00'),
#    Timestamp('1916-10-05 00:00:00')]},
#  1917: {'post': [Timestamp('1917-10-06 00:00:00'),
#    Timestamp('1917-10-15 00:00:00')],
#   'regular': [Timestamp('1917-04-11 00:00:00'),
#    Timestamp('1917-10-04 00:00:00')]},
#  1918: {'post': [Timestamp('1918-09-05 00:00:00'),
#    Timestamp('1918-09-11 00:00:00')],
#   'regular': [Timestamp('1918-04-15 00:00:00'),
#    Timestamp('1918-09-02 00:00:00')]},
#  1919: {'post': [Timestamp('1919-10-01 00:00:00'),
#    Timestamp('1919-10-09 00:00:00')],
#   'regular': [Timestamp('1919-04-19 00:00:00'),
#    Timestamp('1919-09-29 00:00:00')]},
#  1920: {'post': [Timestamp('1920-10-05 00:00:00'),
#    Timestamp('1920-10-12 00:00:00')],
#   'regular': [Timestamp('1920-04-14 00:00:00'),
#    Timestamp('1920-10-03 00:00:00')]},
#  1921: {'post': [Timestamp('1921-10-05 00:00:00'),
#    Timestamp('1921-10-13 00:00:00')],
#   'regular': [Timestamp('1921-04-13 00:00:00'),
#    Timestamp('1921-10-02 00:00:00')]},
#  1922: {'post': [Timestamp('1922-10-04 00:00:00'),
#    Timestamp('1922-10-08 00:00:00')],
#   'regular': [Timestamp('1922-04-12 00:00:00'),
#    Timestamp('1922-10-01 00:00:00')]},
#  1923: {'post': [Timestamp('1923-10-10 00:00:00'),
#    Timestamp('1923-10-15 00:00:00')],
#   'regular': [Timestamp('1923-04-17 00:00:00'),
#    Timestamp('1923-10-07 00:00:00')]},
#  1924: {'post': [Timestamp('1924-10-04 00:00:00'),
#    Timestamp('1924-10-10 00:00:00')],
#   'regular': [Timestamp('1924-04-15 00:00:00'),
#    Timestamp('1924-09-30 00:00:00')]},
#  1925: {'post': [Timestamp('1925-10-07 00:00:00'),
#    Timestamp('1925-10-15 00:00:00')],
#   'regular': [Timestamp('1925-04-14 00:00:00'),
#    Timestamp('1925-10-04 00:00:00')]},
#  1926: {'post': [Timestamp('1926-10-02 00:00:00'),
#    Timestamp('1926-10-10 00:00:00')],
#   'regular': [Timestamp('1926-04-13 00:00:00'),
#    Timestamp('1926-09-29 00:00:00')]},
#  1927: {'post': [Timestamp('1927-10-05 00:00:00'),
#    Timestamp('1927-10-08 00:00:00')],
#   'regular': [Timestamp('1927-04-12 00:00:00'),
#    Timestamp('1927-10-02 00:00:00')]},
#  1928: {'post': [Timestamp('1928-10-04 00:00:00'),
#    Timestamp('1928-10-09 00:00:00')],
#   'regular': [Timestamp('1928-04-10 00:00:00'),
#    Timestamp('1928-09-30 00:00:00')]},
#  1929: {'post': [Timestamp('1929-10-08 00:00:00'),
#    Timestamp('1929-10-14 00:00:00')],
#   'regular': [Timestamp('1929-04-16 00:00:00'),
#    Timestamp('1929-10-06 00:00:00')]},
#  1930: {'post': [Timestamp('1930-10-01 00:00:00'),
#    Timestamp('1930-10-08 00:00:00')],
#   'regular': [Timestamp('1930-04-14 00:00:00'),
#    Timestamp('1930-09-28 00:00:00')]},
#  1931: {'post': [Timestamp('1931-10-01 00:00:00'),
#    Timestamp('1931-10-10 00:00:00')],
#   'regular': [Timestamp('1931-04-14 00:00:00'),
#    Timestamp('1931-09-27 00:00:00')]},
#  1932: {'post': [Timestamp('1932-09-28 00:00:00'),
#    Timestamp('1932-10-02 00:00:00')],
#   'regular': [Timestamp('1932-04-11 00:00:00'),
#    Timestamp('1932-09-25 00:00:00')]},
#  1933: {'post': [Timestamp('1933-10-03 00:00:00'),
#    Timestamp('1933-10-07 00:00:00')],
#   'regular': [Timestamp('1933-04-12 00:00:00'),
#    Timestamp('1933-10-01 00:00:00')]},
#  1934: {'post': [Timestamp('1934-10-03 00:00:00'),
#    Timestamp('1934-10-09 00:00:00')],
#   'regular': [Timestamp('1934-04-17 00:00:00'),
#    Timestamp('1934-09-30 00:00:00')]},
#  1935: {'post': [Timestamp('1935-10-02 00:00:00'),
#    Timestamp('1935-10-07 00:00:00')],
#   'regular': [Timestamp('1935-04-16 00:00:00'),
#    Timestamp('1935-09-29 00:00:00')]},
#  1936: {'post': [Timestamp('1936-09-30 00:00:00'),
#    Timestamp('1936-10-06 00:00:00')],
#   'regular': [Timestamp('1936-04-14 00:00:00'),
#    Timestamp('1936-09-27 00:00:00')]},
#  1937: {'post': [Timestamp('1937-10-06 00:00:00'),
#    Timestamp('1937-10-10 00:00:00')],
#   'regular': [Timestamp('1937-04-19 00:00:00'),
#    Timestamp('1937-10-03 00:00:00')]},
#  1938: {'post': [Timestamp('1938-10-05 00:00:00'),
#    Timestamp('1938-10-09 00:00:00')],
#   'regular': [Timestamp('1938-04-18 00:00:00'),
#    Timestamp('1938-10-02 00:00:00')]},
#  1939: {'post': [Timestamp('1939-10-04 00:00:00'),
#    Timestamp('1939-10-08 00:00:00')],
#   'regular': [Timestamp('1939-04-17 00:00:00'),
#    Timestamp('1939-10-01 00:00:00')]},
#  1940: {'post': [Timestamp('1940-10-02 00:00:00'),
#    Timestamp('1940-10-08 00:00:00')],
#   'regular': [Timestamp('1940-04-16 00:00:00'),
#    Timestamp('1940-09-29 00:00:00')]},
#  1941: {'post': [Timestamp('1941-10-01 00:00:00'),
#    Timestamp('1941-10-06 00:00:00')],
#   'regular': [Timestamp('1941-04-14 00:00:00'),
#    Timestamp('1941-09-28 00:00:00')]},
#  1942: {'post': [Timestamp('1942-09-30 00:00:00'),
#    Timestamp('1942-10-05 00:00:00')],
#   'regular': [Timestamp('1942-04-14 00:00:00'),
#    Timestamp('1942-09-27 00:00:00')]},
#  1943: {'post': [Timestamp('1943-10-05 00:00:00'),
#    Timestamp('1943-10-11 00:00:00')],
#   'regular': [Timestamp('1943-04-20 00:00:00'),
#    Timestamp('1943-10-03 00:00:00')]},
#  1944: {'post': [Timestamp('1944-10-04 00:00:00'),
#    Timestamp('1944-10-09 00:00:00')],
#   'regular': [Timestamp('1944-04-18 00:00:00'),
#    Timestamp('1944-10-01 00:00:00')]},
#  1945: {'post': [Timestamp('1945-10-03 00:00:00'),
#    Timestamp('1945-10-10 00:00:00')],
#   'regular': [Timestamp('1945-04-17 00:00:00'),
#    Timestamp('1945-09-30 00:00:00')]},
#  1946: {'post': [Timestamp('1946-10-06 00:00:00'),
#    Timestamp('1946-10-15 00:00:00')],
#   'regular': [Timestamp('1946-04-16 00:00:00'),
#    Timestamp('1946-10-03 00:00:00')]},
#  1947: {'post': [Timestamp('1947-09-30 00:00:00'),
#    Timestamp('1947-10-06 00:00:00')],
#   'regular': [Timestamp('1947-04-15 00:00:00'),
#    Timestamp('1947-09-28 00:00:00')]},
#  1948: {'post': [Timestamp('1948-10-06 00:00:00'),
#    Timestamp('1948-10-11 00:00:00')],
#   'regular': [Timestamp('1948-04-19 00:00:00'),
#    Timestamp('1948-10-04 00:00:00')]},
#  1949: {'post': [Timestamp('1949-10-05 00:00:00'),
#    Timestamp('1949-10-09 00:00:00')],
#   'regular': [Timestamp('1949-04-18 00:00:00'),
#    Timestamp('1949-10-02 00:00:00')]},
#  1950: {'post': [Timestamp('1950-10-04 00:00:00'),
#    Timestamp('1950-10-07 00:00:00')],
#   'regular': [Timestamp('1950-04-18 00:00:00'),
#    Timestamp('1950-10-01 00:00:00')]},
#  1951: {'post': [Timestamp('1951-10-04 00:00:00'),
#    Timestamp('1951-10-10 00:00:00')],
#   'regular': [Timestamp('1951-04-16 00:00:00'),
#    Timestamp('1951-10-03 00:00:00')]},
#  1952: {'post': [Timestamp('1952-10-01 00:00:00'),
#    Timestamp('1952-10-07 00:00:00')],
#   'regular': [Timestamp('1952-04-15 00:00:00'),
#    Timestamp('1952-09-28 00:00:00')]},
#  1953: {'post': [Timestamp('1953-09-30 00:00:00'),
#    Timestamp('1953-10-05 00:00:00')],
#   'regular': [Timestamp('1953-04-13 00:00:00'),
#    Timestamp('1953-09-27 00:00:00')]},
#  1954: {'post': [Timestamp('1954-09-29 00:00:00'),
#    Timestamp('1954-10-02 00:00:00')],
#   'regular': [Timestamp('1954-04-13 00:00:00'),
#    Timestamp('1954-09-26 00:00:00')]},
#  1955: {'post': [Timestamp('1955-09-28 00:00:00'),
#    Timestamp('1955-10-04 00:00:00')],
#   'regular': [Timestamp('1955-04-11 00:00:00'),
#    Timestamp('1955-09-25 00:00:00')]},
#  1956: {'post': [Timestamp('1956-10-03 00:00:00'),
#    Timestamp('1956-10-10 00:00:00')],
#   'regular': [Timestamp('1956-04-17 00:00:00'),
#    Timestamp('1956-09-30 00:00:00')]},
#  1957: {'post': [Timestamp('1957-10-02 00:00:00'),
#    Timestamp('1957-10-10 00:00:00')],
#   'regular': [Timestamp('1957-04-15 00:00:00'),
#    Timestamp('1957-09-29 00:00:00')]},
#  1958: {'post': [Timestamp('1958-10-01 00:00:00'),
#    Timestamp('1958-10-09 00:00:00')],
#   'regular': [Timestamp('1958-04-14 00:00:00'),
#    Timestamp('1958-09-28 00:00:00')]},
#  1959: {'post': [Timestamp('1959-10-01 00:00:00'),
#    Timestamp('1959-10-08 00:00:00')],
#   'regular': [Timestamp('1959-04-09 00:00:00'),
#    Timestamp('1959-09-29 00:00:00')]},
#  1960: {'post': [Timestamp('1960-10-05 00:00:00'),
#    Timestamp('1960-10-13 00:00:00')],
#   'regular': [Timestamp('1960-04-12 00:00:00'),
#    Timestamp('1960-10-02 00:00:00')]},
#  1961: {'post': [Timestamp('1961-10-04 00:00:00'),
#    Timestamp('1961-10-09 00:00:00')],
#   'regular': [Timestamp('1961-04-10 00:00:00'),
#    Timestamp('1961-10-01 00:00:00')]},
#  1962: {'post': [Timestamp('1962-10-04 00:00:00'),
#    Timestamp('1962-10-16 00:00:00')],
#   'regular': [Timestamp('1962-04-09 00:00:00'),
#    Timestamp('1962-10-03 00:00:00')]},
#  1963: {'post': [Timestamp('1963-10-02 00:00:00'),
#    Timestamp('1963-10-06 00:00:00')],
#   'regular': [Timestamp('1963-04-08 00:00:00'),
#    Timestamp('1963-09-29 00:00:00')]},
#  1964: {'post': [Timestamp('1964-10-07 00:00:00'),
#    Timestamp('1964-10-15 00:00:00')],
#   'regular': [Timestamp('1964-04-13 00:00:00'),
#    Timestamp('1964-10-04 00:00:00')]},
#  1965: {'post': [Timestamp('1965-10-06 00:00:00'),
#    Timestamp('1965-10-14 00:00:00')],
#   'regular': [Timestamp('1965-04-12 00:00:00'),
#    Timestamp('1965-10-03 00:00:00')]},
#  1966: {'post': [Timestamp('1966-10-05 00:00:00'),
#    Timestamp('1966-10-09 00:00:00')],
#   'regular': [Timestamp('1966-04-11 00:00:00'),
#    Timestamp('1966-10-02 00:00:00')]},
#  1967: {'post': [Timestamp('1967-10-04 00:00:00'),
#    Timestamp('1967-10-12 00:00:00')],
#   'regular': [Timestamp('1967-04-10 00:00:00'),
#    Timestamp('1967-10-01 00:00:00')]},
#  1968: {'post': [Timestamp('1968-10-02 00:00:00'),
#    Timestamp('1968-10-10 00:00:00')],
#   'regular': [Timestamp('1968-04-10 00:00:00'),
#    Timestamp('1968-09-29 00:00:00')]},
#  1969: {'post': [Timestamp('1969-10-04 00:00:00'),
#    Timestamp('1969-10-16 00:00:00')],
#   'regular': [Timestamp('1969-04-07 00:00:00'),
#    Timestamp('1969-10-02 00:00:00')]},
#  1970: {'post': [Timestamp('1970-10-03 00:00:00'),
#    Timestamp('1970-10-15 00:00:00')],
#   'regular': [Timestamp('1970-04-06 00:00:00'),
#    Timestamp('1970-10-01 00:00:00')]},
#  1971: {'post': [Timestamp('1971-10-02 00:00:00'),
#    Timestamp('1971-10-17 00:00:00')],
#   'regular': [Timestamp('1971-04-05 00:00:00'),
#    Timestamp('1971-09-30 00:00:00')]},
#  1972: {'post': [Timestamp('1972-10-07 00:00:00'),
#    Timestamp('1972-10-22 00:00:00')],
#   'regular': [Timestamp('1972-04-15 00:00:00'),
#    Timestamp('1972-10-04 00:00:00')]},
#  1973: {'post': [Timestamp('1973-10-06 00:00:00'),
#    Timestamp('1973-10-21 00:00:00')],
#   'regular': [Timestamp('1973-04-05 00:00:00'),
#    Timestamp('1973-10-01 00:00:00')]},
#  1974: {'post': [Timestamp('1974-10-05 00:00:00'),
#    Timestamp('1974-10-17 00:00:00')],
#   'regular': [Timestamp('1974-04-04 00:00:00'),
#    Timestamp('1974-10-02 00:00:00')]},
#  1975: {'post': [Timestamp('1975-10-04 00:00:00'),
#    Timestamp('1975-10-22 00:00:00')],
#   'regular': [Timestamp('1975-04-07 00:00:00'),
#    Timestamp('1975-09-28 00:00:00')]},
#  1976: {'post': [Timestamp('1976-10-09 00:00:00'),
#    Timestamp('1976-10-21 00:00:00')],
#   'regular': [Timestamp('1976-04-08 00:00:00'),
#    Timestamp('1976-10-03 00:00:00')]},
#  1977: {'post': [Timestamp('1977-10-04 00:00:00'),
#    Timestamp('1977-10-18 00:00:00')],
#   'regular': [Timestamp('1977-04-06 00:00:00'),
#    Timestamp('1977-10-02 00:00:00')]},
#  1978: {'post': [Timestamp('1978-10-03 00:00:00'),
#    Timestamp('1978-10-17 00:00:00')],
#   'regular': [Timestamp('1978-04-05 00:00:00'),
#    Timestamp('1978-10-02 00:00:00')]},
#  1979: {'post': [Timestamp('1979-10-02 00:00:00'),
#    Timestamp('1979-10-17 00:00:00')],
#   'regular': [Timestamp('1979-04-04 00:00:00'),
#    Timestamp('1979-09-30 00:00:00')]},
#  1980: {'post': [Timestamp('1980-10-07 00:00:00'),
#    Timestamp('1980-10-21 00:00:00')],
#   'regular': [Timestamp('1980-04-09 00:00:00'),
#    Timestamp('1980-10-06 00:00:00')]},
#  1981: {'post': [Timestamp('1981-10-06 00:00:00'),
#    Timestamp('1981-10-28 00:00:00')],
#   'regular': [Timestamp('1981-04-08 00:00:00'),
#    Timestamp('1981-10-05 00:00:00')]},
#  1982: {'post': [Timestamp('1982-10-05 00:00:00'),
#    Timestamp('1982-10-20 00:00:00')],
#   'regular': [Timestamp('1982-04-05 00:00:00'),
#    Timestamp('1982-10-03 00:00:00')]},
#  1983: {'post': [Timestamp('1983-10-04 00:00:00'),
#    Timestamp('1983-10-16 00:00:00')],
#   'regular': [Timestamp('1983-04-04 00:00:00'),
#    Timestamp('1983-10-02 00:00:00')]},
#  1984: {'post': [Timestamp('1984-10-02 00:00:00'),
#    Timestamp('1984-10-14 00:00:00')],
#   'regular': [Timestamp('1984-04-02 00:00:00'),
#    Timestamp('1984-09-30 00:00:00')]},
#  1985: {'post': [Timestamp('1985-10-08 00:00:00'),
#    Timestamp('1985-10-27 00:00:00')],
#   'regular': [Timestamp('1985-04-08 00:00:00'),
#    Timestamp('1985-10-06 00:00:00')]},
#  1986: {'post': [Timestamp('1986-10-07 00:00:00'),
#    Timestamp('1986-10-27 00:00:00')],
#   'regular': [Timestamp('1986-04-07 00:00:00'),
#    Timestamp('1986-10-05 00:00:00')]},
#  1987: {'post': [Timestamp('1987-10-06 00:00:00'),
#    Timestamp('1987-10-25 00:00:00')],
#   'regular': [Timestamp('1987-04-06 00:00:00'),
#    Timestamp('1987-10-04 00:00:00')]},
#  1988: {'post': [Timestamp('1988-10-04 00:00:00'),
#    Timestamp('1988-10-20 00:00:00')],
#   'regular': [Timestamp('1988-04-04 00:00:00'),
#    Timestamp('1988-10-02 00:00:00')]},
#  1989: {'post': [Timestamp('1989-10-03 00:00:00'),
#    Timestamp('1989-10-28 00:00:00')],
#   'regular': [Timestamp('1989-04-03 00:00:00'),
#    Timestamp('1989-10-01 00:00:00')]},
#  1990: {'post': [Timestamp('1990-10-04 00:00:00'),
#    Timestamp('1990-10-20 00:00:00')],
#   'regular': [Timestamp('1990-04-09 00:00:00'),
#    Timestamp('1990-10-03 00:00:00')]},
#  1991: {'post': [Timestamp('1991-10-08 00:00:00'),
#    Timestamp('1991-10-27 00:00:00')],
#   'regular': [Timestamp('1991-04-08 00:00:00'),
#    Timestamp('1991-10-06 00:00:00')]},
#  1992: {'post': [Timestamp('1992-10-06 00:00:00'),
#    Timestamp('1992-10-24 00:00:00')],
#   'regular': [Timestamp('1992-04-06 00:00:00'),
#    Timestamp('1992-10-04 00:00:00')]},
#  1993: {'post': [Timestamp('1993-10-05 00:00:00'),
#    Timestamp('1993-10-23 00:00:00')],
#   'regular': [Timestamp('1993-04-05 00:00:00'),
#    Timestamp('1993-10-03 00:00:00')]},
#  1994: {'post': [],
#   'regular': [Timestamp('1994-04-03 00:00:00'),
#    Timestamp('1994-08-11 00:00:00')]},
#  1995: {'post': [Timestamp('1995-10-03 00:00:00'),
#    Timestamp('1995-10-28 00:00:00')],
#   'regular': [Timestamp('1995-04-25 00:00:00'),
#    Timestamp('1995-10-02 00:00:00')]},
#  1996: {'post': [Timestamp('1996-10-01 00:00:00'),
#    Timestamp('1996-10-26 00:00:00')],
#   'regular': [Timestamp('1996-03-31 00:00:00'),
#    Timestamp('1996-09-29 00:00:00')]},
#  1997: {'post': [Timestamp('1997-09-30 00:00:00'),
#    Timestamp('1997-10-26 00:00:00')],
#   'regular': [Timestamp('1997-04-01 00:00:00'),
#    Timestamp('1997-09-28 00:00:00')]},
#  1998: {'post': [Timestamp('1998-09-29 00:00:00'),
#    Timestamp('1998-10-21 00:00:00')],
#   'regular': [Timestamp('1998-03-31 00:00:00'),
#    Timestamp('1998-09-28 00:00:00')]},
#  1999: {'post': [Timestamp('1999-10-05 00:00:00'),
#    Timestamp('1999-10-27 00:00:00')],
#   'regular': [Timestamp('1999-04-04 00:00:00'),
#    Timestamp('1999-10-04 00:00:00')]},
#  2000: {'post': [Timestamp('2000-10-03 00:00:00'),
#    Timestamp('2000-10-26 00:00:00')],
#   'regular': [Timestamp('2000-03-29 00:00:00'),
#    Timestamp('2000-10-01 00:00:00')]},
#  2001: {'post': [Timestamp('2001-10-09 00:00:00'),
#    Timestamp('2001-11-04 00:00:00')],
#   'regular': [Timestamp('2001-04-01 00:00:00'),
#    Timestamp('2001-10-07 00:00:00')]},
#  2002: {'post': [Timestamp('2002-10-01 00:00:00'),
#    Timestamp('2002-10-27 00:00:00')],
#   'regular': [Timestamp('2002-03-31 00:00:00'),
#    Timestamp('2002-09-29 00:00:00')]},
#  2003: {'post': [Timestamp('2003-09-30 00:00:00'),
#    Timestamp('2003-10-25 00:00:00')],
#   'regular': [Timestamp('2003-03-30 00:00:00'),
#    Timestamp('2003-09-28 00:00:00')]},
#  2004: {'post': [Timestamp('2004-10-05 00:00:00'),
#    Timestamp('2004-10-27 00:00:00')],
#   'regular': [Timestamp('2004-03-30 00:00:00'),
#    Timestamp('2004-10-03 00:00:00')]},
#  2005: {'post': [Timestamp('2005-10-04 00:00:00'),
#    Timestamp('2005-10-26 00:00:00')],
#   'regular': [Timestamp('2005-04-03 00:00:00'),
#    Timestamp('2005-10-02 00:00:00')]},
#  2006: {'post': [Timestamp('2006-10-03 00:00:00'),
#    Timestamp('2006-10-27 00:00:00')],
#   'regular': [Timestamp('2006-04-02 00:00:00'),
#    Timestamp('2006-10-01 00:00:00')]},
#  2007: {'post': [Timestamp('2007-10-03 00:00:00'),
#    Timestamp('2007-10-28 00:00:00')],
#   'regular': [Timestamp('2007-04-01 00:00:00'),
#    Timestamp('2007-10-01 00:00:00')]},
#  2008: {'post': [Timestamp('2008-10-01 00:00:00'),
#    Timestamp('2008-10-27 00:00:00')],
#   'regular': [Timestamp('2008-03-25 00:00:00'),
#    Timestamp('2008-09-30 00:00:00')]},
#  2009: {'post': [Timestamp('2009-10-07 00:00:00'),
#    Timestamp('2009-11-04 00:00:00')],
#   'regular': [Timestamp('2009-04-05 00:00:00'),
#    Timestamp('2009-10-06 00:00:00')]},
#  2010: {'post': [Timestamp('2010-10-06 00:00:00'),
#    Timestamp('2010-11-01 00:00:00')],
#   'regular': [Timestamp('2010-04-04 00:00:00'),
#    Timestamp('2010-10-03 00:00:00')]},
#  2011: {'post': [Timestamp('2011-09-30 00:00:00'),
#    Timestamp('2011-10-28 00:00:00')],
#   'regular': [Timestamp('2011-03-31 00:00:00'),
#    Timestamp('2011-09-28 00:00:00')]},
#  2012: {'post': [Timestamp('2012-10-05 00:00:00'),
#    Timestamp('2012-10-28 00:00:00')],
#   'regular': [Timestamp('2012-03-28 00:00:00'),
#    Timestamp('2012-10-03 00:00:00')]},
#  2013: {'post': [Timestamp('2013-10-01 00:00:00'),
#    Timestamp('2013-10-30 00:00:00')],
#   'regular': [Timestamp('2013-03-31 00:00:00'),
#    Timestamp('2013-09-30 00:00:00')]},
#  2014: {'post': [Timestamp('2014-09-30 00:00:00'),
#    Timestamp('2014-10-29 00:00:00')],
#   'regular': [Timestamp('2014-03-22 00:00:00'),
#    Timestamp('2014-09-28 00:00:00')]},
#  2015: {'post': [Timestamp('2015-10-06 00:00:00'),
#    Timestamp('2015-11-01 00:00:00')],
#   'regular': [Timestamp('2015-04-05 00:00:00'),
#    Timestamp('2015-10-04 00:00:00')]},
#  2016: {'post': [Timestamp('2016-10-04 00:00:00'),
#    Timestamp('2016-11-02 00:00:00')],
#   'regular': [Timestamp('2016-04-03 00:00:00'),
#    Timestamp('2016-10-02 00:00:00')]},
#  2017: {'post': [Timestamp('2017-10-03 00:00:00'),
#    Timestamp('2017-11-01 00:00:00')],
#   'regular': [Timestamp('2017-04-02 00:00:00'),
#    Timestamp('2017-10-01 00:00:00')]},
#  2018: {'post': [Timestamp('2018-10-02 00:00:00'),
#    Timestamp('2018-10-28 00:00:00')],
#   'regular': [Timestamp('2018-03-29 00:00:00'),
#    Timestamp('2018-10-01 00:00:00')]},
#  2019: {'post': [Timestamp('2019-10-01 00:00:00'),
#    Timestamp('2019-10-30 00:00:00')],
#   'regular': [Timestamp('2019-03-20 00:00:00'),
#    Timestamp('2019-09-29 00:00:00')]},
#  2020: {'post': [Timestamp('2020-09-29 00:00:00'),
#    Timestamp('2020-10-27 00:00:00')],
#   'regular': [Timestamp('2020-07-23 00:00:00'),
#    Timestamp('2020-09-27 00:00:00')]},
#  2021: {'post': [Timestamp('2021-10-05 00:00:00'),
#    Timestamp('2021-11-02 00:00:00')],
#   'regular': [Timestamp('2021-04-01 00:00:00'),
#    Timestamp('2021-10-03 00:00:00')]}}

# %%
# !pip install sportsipy
# Out:
# Collecting sportsipy
#   Downloading sportsipy-0.6.0-py3-none-any.whl (499 kB)
#      |████████████████████████████████| 499 kB 12.7 MB/s
# Requirement already satisfied: pandas>=0.24.1 in /usr/local/lib/python3.7/dist-packages (from sportsipy) (1.3.5)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from sportsipy) (2.23.0)
# Collecting pyquery>=1.4.0
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.1->sportsipy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.1->sportsipy) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.1->sportsipy) (1.21.5)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery>=1.4.0->sportsipy) (4.2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.1->sportsipy) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->sportsipy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->sportsipy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->sportsipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->sportsipy) (2021.10.8)
# Installing collected packages: cssselect, pyquery, sportsipy
# Successfully installed cssselect-1.1.0 pyquery-1.4.3 sportsipy-0.6.0

# %%
from sportsipy.mlb.schedule import Schedule

# %%
s = Schedule('HOU', year = 2020)

# %%
s.dataframe
# Out:
#                  attendance    boxscore_index                  date  \
# HOU/HOU202007240       None  HOU/HOU202007240        Friday, Jul 24
# HOU/HOU202007250       None  HOU/HOU202007250      Saturday, Jul 25
# HOU/HOU202007260       None  HOU/HOU202007260        Sunday, Jul 26
# HOU/HOU202007270       None  HOU/HOU202007270        Monday, Jul 27
# HOU/HOU202007280       None  HOU/HOU202007280       Tuesday, Jul 28
# HOU/HOU202007290       None  HOU/HOU202007290     Wednesday, Jul 29
# ANA/ANA202007310       None  ANA/ANA202007310        Friday, Jul 31
# ANA/ANA202008010       None  ANA/ANA202008010       Saturday, Aug 1
# ANA/ANA202008020       None  ANA/ANA202008020         Sunday, Aug 2
# ARI/ARI202008040       None  ARI/ARI202008040        Tuesday, Aug 4
# ARI/ARI202008050       None  ARI/ARI202008050      Wednesday, Aug 5
# ARI/ARI202008060       None  ARI/ARI202008060       Thursday, Aug 6
# OAK/OAK202008070       None  OAK/OAK202008070         Friday, Aug 7
# OAK/OAK202008080       None  OAK/OAK202008080       Saturday, Aug 8
# OAK/OAK202008090       None  OAK/OAK202008090         Sunday, Aug 9
# HOU/HOU202008100       None  HOU/HOU202008100        Monday, Aug 10
# HOU/HOU202008110       None  HOU/HOU202008110       Tuesday, Aug 11
# HOU/HOU202008120       None  HOU/HOU202008120     Wednesday, Aug 12
# HOU/HOU202008140       None  HOU/HOU202008140        Friday, Aug 14
# HOU/HOU202008150       None  HOU/HOU202008150      Saturday, Aug 15
# HOU/HOU202008160       None  HOU/HOU202008160        Sunday, Aug 16
# HOU/HOU202008170       None  HOU/HOU202008170        Monday, Aug 17
# HOU/HOU202008180       None  HOU/HOU202008180       Tuesday, Aug 18
# COL/COL202008190       None  COL/COL202008190     Wednesday, Aug 19
# COL/COL202008200       None  COL/COL202008200      Thursday, Aug 20
# SDN/SDN202008210       None  SDN/SDN202008210        Friday, Aug 21
# SDN/SDN202008220       None  SDN/SDN202008220      Saturday, Aug 22
# SDN/SDN202008230       None  SDN/SDN202008230        Sunday, Aug 23
# HOU/HOU202008240       None  HOU/HOU202008240        Monday, Aug 24
# HOU/HOU202008251       None  HOU/HOU202008251   Tuesday, Aug 25 (1)
# HOU/HOU202008252       None  HOU/HOU202008252   Tuesday, Aug 25 (2)
# HOU/HOU202008291       None  HOU/HOU202008291  Saturday, Aug 29 (1)
# HOU/HOU202008292       None  HOU/HOU202008292  Saturday, Aug 29 (2)
# HOU/HOU202009010       None  HOU/HOU202009010        Tuesday, Sep 1
# HOU/HOU202009020       None  HOU/HOU202009020      Wednesday, Sep 2
# HOU/HOU202009030       None  HOU/HOU202009030       Thursday, Sep 3
# ANA/ANA202009040       None  ANA/ANA202009040         Friday, Sep 4
# ANA/ANA202009051       None  ANA/ANA202009051   Saturday, Sep 5 (1)
# ANA/ANA202009052       None  ANA/ANA202009052   Saturday, Sep 5 (2)
# ANA/ANA202009060       None  ANA/ANA202009060         Sunday, Sep 6
# OAK/OAK202009070       None  OAK/OAK202009070         Monday, Sep 7
# OAK/OAK202009081       None  OAK/OAK202009081    Tuesday, Sep 8 (1)
# OAK/OAK202009082       None  OAK/OAK202009082    Tuesday, Sep 8 (2)
# OAK/OAK202009090       None  OAK/OAK202009090      Wednesday, Sep 9
# OAK/OAK202009100       None  OAK/OAK202009100      Thursday, Sep 10
# LAN/LAN202009120       None  LAN/LAN202009120      Saturday, Sep 12
# LAN/LAN202009130       None  LAN/LAN202009130        Sunday, Sep 13
# HOU/HOU202009150       None  HOU/HOU202009150       Tuesday, Sep 15
# HOU/HOU202009160       None  HOU/HOU202009160     Wednesday, Sep 16
# HOU/HOU202009170       None  HOU/HOU202009170      Thursday, Sep 17
# HOU/HOU202009180       None  HOU/HOU202009180        Friday, Sep 18
# HOU/HOU202009190       None  HOU/HOU202009190      Saturday, Sep 19
# HOU/HOU202009200       None  HOU/HOU202009200        Sunday, Sep 20
# SEA/SEA202009210       None  SEA/SEA202009210        Monday, Sep 21
# SEA/SEA202009220       None  SEA/SEA202009220       Tuesday, Sep 22
# SEA/SEA202009230       None  SEA/SEA202009230     Wednesday, Sep 23
# TEX/TEX202009240       None  TEX/TEX202009240      Thursday, Sep 24
# TEX/TEX202009250       None  TEX/TEX202009250        Friday, Sep 25
# TEX/TEX202009260       None  TEX/TEX202009260      Saturday, Sep 26
# TEX/TEX202009270       None  TEX/TEX202009270        Sunday, Sep 27
#
#                    datetime  game_number_for_day day_or_night  game  \
# HOU/HOU202007240 2020-07-24                    1        Night     1
# HOU/HOU202007250 2020-07-25                    1          Day     2
# HOU/HOU202007260 2020-07-26                    1          Day     3
# HOU/HOU202007270 2020-07-27                    1        Night     4
# HOU/HOU202007280 2020-07-28                    1        Night     5
# HOU/HOU202007290 2020-07-29                    1        Night     6
# ANA/ANA202007310 2020-07-31                    1        Night     7
# ANA/ANA202008010 2020-08-01                    1          Day     8
# ANA/ANA202008020 2020-08-02                    1          Day     9
# ARI/ARI202008040 2020-08-04                    1        Night    10
# ARI/ARI202008050 2020-08-05                    1        Night    11
# ARI/ARI202008060 2020-08-06                    1          Day    12
# OAK/OAK202008070 2020-08-07                    1        Night    13
# OAK/OAK202008080 2020-08-08                    1          Day    14
# OAK/OAK202008090 2020-08-09                    1          Day    15
# HOU/HOU202008100 2020-08-10                    1        Night    16
# HOU/HOU202008110 2020-08-11                    1        Night    17
# HOU/HOU202008120 2020-08-12                    1        Night    18
# HOU/HOU202008140 2020-08-14                    1        Night    19
# HOU/HOU202008150 2020-08-15                    1        Night    20
# HOU/HOU202008160 2020-08-16                    1          Day    21
# HOU/HOU202008170 2020-08-17                    1        Night    22
# HOU/HOU202008180 2020-08-18                    1          Day    23
# COL/COL202008190 2020-08-19                    1        Night    24
# COL/COL202008200 2020-08-20                    1          Day    25
# SDN/SDN202008210 2020-08-21                    1        Night    26
# SDN/SDN202008220 2020-08-22                    1        Night    27
# SDN/SDN202008230 2020-08-23                    1          Day    28
# HOU/HOU202008240 2020-08-24                    1        Night    29
# HOU/HOU202008251 2020-08-25                    1          Day    30
# HOU/HOU202008252 2020-08-25                    2          Day    31
# HOU/HOU202008291 2020-08-29                    1          Day    32
# HOU/HOU202008292 2020-08-29                    2          Day    33
# HOU/HOU202009010 2020-09-01                    1        Night    34
# HOU/HOU202009020 2020-09-02                    1        Night    35
# HOU/HOU202009030 2020-09-03                    1          Day    36
# ANA/ANA202009040 2020-09-04                    1        Night    37
# ANA/ANA202009051 2020-09-05                    1          Day    38
# ANA/ANA202009052 2020-09-05                    2        Night    39
# ANA/ANA202009060 2020-09-06                    1          Day    40
# OAK/OAK202009070 2020-09-07                    1        Night    41
# OAK/OAK202009081 2020-09-08                    1          Day    42
# OAK/OAK202009082 2020-09-08                    2          Day    43
# OAK/OAK202009090 2020-09-09                    1        Night    44
# OAK/OAK202009100 2020-09-10                    1          Day    45
# LAN/LAN202009120 2020-09-12                    1        Night    46
# LAN/LAN202009130 2020-09-13                    1        Night    47
# HOU/HOU202009150 2020-09-15                    1        Night    48
# HOU/HOU202009160 2020-09-16                    1        Night    49
# HOU/HOU202009170 2020-09-17                    1        Night    50
# HOU/HOU202009180 2020-09-18                    1        Night    51
# HOU/HOU202009190 2020-09-19                    1        Night    52
# HOU/HOU202009200 2020-09-20                    1          Day    53
# SEA/SEA202009210 2020-09-21                    1        Night    54
# SEA/SEA202009220 2020-09-22                    1        Night    55
# SEA/SEA202009230 2020-09-23                    1          Day    56
# TEX/TEX202009240 2020-09-24                    1        Night    57
# TEX/TEX202009250 2020-09-25                    1        Night    58
# TEX/TEX202009260 2020-09-26                    1        Night    59
# TEX/TEX202009270 2020-09-27                    1          Day    60
#
#                  game_duration  games_behind  innings  ...        loser  \
# HOU/HOU202007240          2:49           0.0        9  ...     Gonzales
# HOU/HOU202007250          2:53          -1.0        9  ...       Walker
# HOU/HOU202007260          3:41           0.0        9  ...     Devenski
# HOU/HOU202007270          3:04           0.0        9  ...     Graveman
# HOU/HOU202007280          3:19           0.0        9  ...       Valdez
# HOU/HOU202007290          4:44           0.0       13  ...        Sneed
# ANA/ANA202007310          4:21          -0.5        9  ...     Andriese
# ANA/ANA202008010          3:58           0.0       10  ...    Rodriguez
# ANA/ANA202008020          4:37           0.0       11  ...       Barnes
# ARI/ARI202008040          3:09           0.5        9  ...    Bumgarner
# ARI/ARI202008050          3:14           1.5        9  ...    McCullers
# ARI/ARI202008060          3:15           2.5        9  ...      Pressly
# OAK/OAK202008070          4:13           3.5       13  ...        Sneed
# OAK/OAK202008080          2:24           4.5        9  ...       Valdez
# OAK/OAK202008090          2:58           5.5        9  ...       Javier
# HOU/HOU202008100          3:07           4.5        9  ...         Webb
# HOU/HOU202008110          3:52           4.5       10  ...        Sneed
# HOU/HOU202008120          3:25           4.5        9  ...      Baragar
# HOU/HOU202008140          3:10           4.5        9  ...       Cortes
# HOU/HOU202008150          2:30           4.5        9  ...  Margevicius
# HOU/HOU202008160          2:56           4.5        9  ...      Swanson
# HOU/HOU202008170          2:50           3.5        9  ...     Freeland
# HOU/HOU202008180          3:03           2.5       11  ...         Diaz
# COL/COL202008190          3:09           2.5        9  ...   Castellani
# COL/COL202008200          3:31           2.5        9  ...      Marquez
# SDN/SDN202008210          3:41           3.5        9  ...    McCullers
# SDN/SDN202008220          2:41           3.5        9  ...       Bielak
# SDN/SDN202008230          3:04           4.5        9  ...      Paredes
# HOU/HOU202008240          3:25           3.5        9  ...     Sandoval
# HOU/HOU202008251          2:26           4.0        7  ...       Suarez
# HOU/HOU202008252          3:24           4.0        7  ...       Bielak
# HOU/HOU202008291          2:07           2.5        7  ...      Bassitt
# HOU/HOU202008292          2:33           2.5        7  ...       Montas
# HOU/HOU202009010          3:28           3.0       10  ...       Taylor
# HOU/HOU202009020          2:27           2.5        9  ...       Allard
# HOU/HOU202009030          3:11           2.0        9  ...         Lynn
# ANA/ANA202009040          4:27           2.0       11  ...        Raley
# ANA/ANA202009051          3:01           3.5        7  ...      Paredes
# ANA/ANA202009052          2:44           3.5        7  ...  Castellanos
# ANA/ANA202009060          3:28           3.5        9  ...       Valdez
# OAK/OAK202009070          2:55           4.5        9  ...       Javier
# OAK/OAK202009081          2:23           4.5        7  ...      Greinke
# OAK/OAK202009082          2:52           4.5        7  ...    Wendelken
# OAK/OAK202009090          2:53           5.5        9  ...      Pressly
# OAK/OAK202009100          2:18           6.5        9  ...      Urquidy
# LAN/LAN202009120          3:15           6.5        9  ...       Jansen
# LAN/LAN202009130          2:52           6.5        9  ...      Greinke
# HOU/HOU202009150          3:00           5.5        9  ...        Goody
# HOU/HOU202009160          2:36           6.5        9  ...      Pressly
# HOU/HOU202009170          2:33           6.0        9  ...        Lyles
# HOU/HOU202009180          3:08           7.0        9  ...       Garcia
# HOU/HOU202009190          2:37           7.0        9  ...       Weaver
# HOU/HOU202009200          3:04           6.0        9  ...       Guerra
# SEA/SEA202009210          2:34           6.5        9  ...    McCullers
# SEA/SEA202009220          3:06           5.5        9  ...       Sadler
# SEA/SEA202009230          3:09           6.5        9  ...      Greinke
# TEX/TEX202009240          3:11           5.5        9  ...         Lynn
# TEX/TEX202009250          3:15           6.5       10  ...      Paredes
# TEX/TEX202009260          2:44           6.0        9  ...       Bielak
# TEX/TEX202009270          3:28           7.0        9  ...      De Jong
#
#                  opponent_abbr rank  record result runs_allowed  runs_scored  \
# HOU/HOU202007240           SEA    1     1-0    Win            2            8
# HOU/HOU202007250           SEA    1     2-0    Win            2            7
# HOU/HOU202007260           SEA    1     2-1   Loss            7            6
# HOU/HOU202007270           SEA    1     3-1    Win            5            8
# HOU/HOU202007280           LAD    1     3-2   Loss            5            2
# HOU/HOU202007290           LAD    1     3-3   Loss            4            2
# ANA/ANA202007310           LAA    1     4-3    Win            6            9
# ANA/ANA202008010           LAA    1     4-4   Loss            5            4
# ANA/ANA202008020           LAA    1     5-4    Win            5            6
# ARI/ARI202008040           ARI    2     6-4    Win            2            8
# ARI/ARI202008050           ARI    2     6-5   Loss           14            7
# ARI/ARI202008060           ARI    2     6-6   Loss            5            4
# OAK/OAK202008070           OAK    2     6-7   Loss            3            2
# OAK/OAK202008080           OAK    2     6-8   Loss            3            1
# OAK/OAK202008090           OAK    3     6-9   Loss            7            2
# HOU/HOU202008100           SFG    2     7-9    Win            4            6
# HOU/HOU202008110           SFG    3    7-10   Loss            7            6
# HOU/HOU202008120           SFG    3    8-10    Win            1            5
# HOU/HOU202008140           SEA    3    9-10    Win            1           11
# HOU/HOU202008150           SEA    3   10-10    Win            1            2
# HOU/HOU202008160           SEA    2   11-10   Loss            2            3
# HOU/HOU202008170           COL    2   12-10    Win            1            2
# HOU/HOU202008180           COL    2   13-10   Loss            1            2
# COL/COL202008190           COL    2   14-10    Win            6           13
# COL/COL202008200           COL    2   15-10    Win            8           10
# SDN/SDN202008210           SDP    2   15-11   Loss            4            3
# SDN/SDN202008220           SDP    2   15-12   Loss           13            2
# SDN/SDN202008230           SDP    2   15-13   Loss            5            3
# HOU/HOU202008240           LAA    2   16-13    Win            4           11
# HOU/HOU202008251           LAA    2   17-13    Win            3            6
# HOU/HOU202008252           LAA    2   17-14   Loss           12            5
# HOU/HOU202008291           OAK    2   18-14    Win            2            4
# HOU/HOU202008292           OAK    2   19-14    Win            3            6
# HOU/HOU202009010           TEX    2   19-15   Loss            6            5
# HOU/HOU202009020           TEX    2   20-15    Win            1            2
# HOU/HOU202009030           TEX    2   21-15    Win            4            8
# ANA/ANA202009040           LAA    2   21-16   Loss            6            5
# ANA/ANA202009051           LAA    2   21-17   Loss           10            9
# ANA/ANA202009052           LAA    2   21-18   Loss            7            6
# ANA/ANA202009060           LAA    2   21-19   Loss            9            5
# OAK/OAK202009070           OAK    2   21-20   Loss            6            0
# OAK/OAK202009081           OAK    2   21-21   Loss            4            2
# OAK/OAK202009082           OAK    2   22-21    Win            4            5
# OAK/OAK202009090           OAK    2   22-22   Loss            3            2
# OAK/OAK202009100           OAK    2   22-23   Loss            3            1
# LAN/LAN202009120           LAD    2   23-23    Win            5            7
# LAN/LAN202009130           LAD    2   23-24   Loss            8            1
# HOU/HOU202009150           TEX    2   24-24    Win            1            4
# HOU/HOU202009160           TEX    2   24-25   Loss            1            0
# HOU/HOU202009170           TEX    2   25-25    Win            1            2
# HOU/HOU202009180           ARI    2   25-26   Loss            6            3
# HOU/HOU202009190           ARI    2   26-26    Win            2            3
# HOU/HOU202009200           ARI    2   27-26    Win            2            3
# SEA/SEA202009210           SEA    2   27-27   Loss            6            1
# SEA/SEA202009220           SEA    2   28-27    Win            1            6
# SEA/SEA202009230           SEA    2   28-28   Loss            3            2
# TEX/TEX202009240           TEX    2   29-28    Win            4           12
# TEX/TEX202009250           TEX    2   29-29   Loss            5            4
# TEX/TEX202009260           TEX    2   29-30   Loss            6            1
# TEX/TEX202009270           TEX    2   29-31   Loss            8            4
#
#                       save    streak       winner
# HOU/HOU202007240      None         +    Verlander
# HOU/HOU202007250      None        ++    McCullers
# HOU/HOU202007260  Williams         -    Altavilla
# HOU/HOU202007270     Osuna         +       Bielak
# HOU/HOU202007280    Jansen         -      Kolarek
# HOU/HOU202007290      None        --      Santana
# ANA/ANA202007310    Scrubb         +       Bielak
# ANA/ANA202008010      None         -      Buchter
# ANA/ANA202008020      None         +       Taylor
# ARI/ARI202008040      None        ++       Javier
# ARI/ARI202008050      None         -          Ray
# ARI/ARI202008060      None        --       Guerra
# OAK/OAK202008070      None       ---    Wendelken
# OAK/OAK202008080  Hendriks      ----       Montas
# OAK/OAK202008090     Smith     -----      Luzardo
# HOU/HOU202008100   Pressly         +    McCullers
# HOU/HOU202008110    Rogers         -         Gott
# HOU/HOU202008120      None         +      Greinke
# HOU/HOU202008140      None        ++       Valdez
# HOU/HOU202008150   Pressly       +++       Javier
# HOU/HOU202008160      None      ++++      Pressly
# HOU/HOU202008170    Taylor     +++++       Bielak
# HOU/HOU202008180      None    ++++++       Scrubb
# COL/COL202008190      None   +++++++       Valdez
# COL/COL202008200   Pressly  ++++++++      Paredes
# SDN/SDN202008210     Pagan         -       Guerra
# SDN/SDN202008220      None        --       Davies
# SDN/SDN202008230     Pagan       ---      Stammen
# HOU/HOU202008240      None         +       Valdez
# HOU/HOU202008251   Pressly        ++       Javier
# HOU/HOU202008252      None         -         Pena
# HOU/HOU202008291   Pressly         +    McCullers
# HOU/HOU202008292   Pressly        ++      Greinke
# HOU/HOU202009010   Montero         -    Hernandez
# HOU/HOU202009020   Pressly         +       Javier
# HOU/HOU202009030      None        ++      Greinke
# ANA/ANA202009040      None         -     Andriese
# ANA/ANA202009051      None        --         Pena
# ANA/ANA202009052   Buttrey       ---      Ramirez
# ANA/ANA202009060      None      ----       Mayers
# OAK/OAK202009070      None     -----      Bassitt
# OAK/OAK202009081  Hendriks    ------       Montas
# OAK/OAK202009082   Pressly         +      Paredes
# OAK/OAK202009090      None         -     Hendriks
# OAK/OAK202009100  Hendriks        --       Manaea
# LAN/LAN202009120   Pressly         +        James
# LAN/LAN202009130      None         -     Gonzalez
# HOU/HOU202009150   Pressly         +      Urquidy
# HOU/HOU202009160      None         -       Gibson
# HOU/HOU202009170     Raley         +       Valdez
# HOU/HOU202009180  Crichton         -       Gallen
# HOU/HOU202009190   Pressly         +      Paredes
# HOU/HOU202009200   Pressly        ++       Taylor
# SEA/SEA202009210      None         -     Gonzales
# SEA/SEA202009220      None         +       Valdez
# SEA/SEA202009230    Hirano         -  Margevicius
# TEX/TEX202009240      None         +       Javier
# TEX/TEX202009250      None         -       Martin
# TEX/TEX202009260      None        --       Herget
# TEX/TEX202009270      None       ---     Benjamin
#
# [60 rows x 21 columns]
